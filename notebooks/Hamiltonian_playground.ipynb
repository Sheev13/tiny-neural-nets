# %%
import torch
import matplotlib.pyplot as plt
from tqdm import tqdm

import sys

sys.path.append("../")

from data import generate_segp_dataset, autocorrelation
from neural_networks.bayesian_nn import HamiltonianPerceptron

torch.set_default_dtype(torch.float64)
plt.style.use('ggplot')

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# torch.manual_seed(3)
# x, y = generate_segp_dataset(input_lower=-2.0, input_upper=2.0, num_points=50, noise_level=0.05, lengthscale=1.0)
torch.manual_seed(49)
x, y = generate_segp_dataset(input_lower=-2.0, input_upper=2.0, num_points=10, noise_level=0.1, lengthscale=1.0)

plt.scatter(x, y, color='C1', marker='2')
plt.ylim([-2.0, 2.0])
plt.xlim([-2.5, 2.5])
plt.grid(True)
plt.title('Dataset')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
granularity = 21
stepsizes = torch.logspace(-2.1, -4, granularity)
alphas = torch.zeros((granularity,))
net = HamiltonianPerceptron(100, nonlinearity='tanh', prior='Gaussian', bias=True)

progress = tqdm(enumerate(stepsizes))
for i, stepsize in progress:
    _, alpha, _ = net.hamiltonian_monte_carlo(x, y, simulation_steps=50, step_size=stepsize, leapfrog_steps=1000, pbar=False, metropolis_adjust=True)
    alphas[i] = alpha
    progress.set_postfix({"acceptance": alpha})
# Out:
# 0it [00:00, ?it/s]
# 21it [21:34, 61.62s/it, acceptance=1]

# %%
alphas = torch.flip(alphas, dims=(0,))

# %%
plt.plot(stepsizes, alphas)
plt.title('Average Acceptance Probability vs HMC Leapfrog Step Size')
plt.xlabel('Step Size')
plt.ylabel(r'$\bar{\alpha}$', rotation=0)
plt.xscale('log')
plt.show()

# %%
net = HamiltonianPerceptron(100, nonlinearity='tanh', prior='Gaussian', bias=True)
steps = 500
posterior_samples, alpha, metrics = net.hamiltonian_monte_carlo(x, y, simulation_steps=steps, step_size=1e-4, leapfrog_steps=5000, metropolis_adjust=True)
print(alpha)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
#  16%|█▌        | 79/500 [08:10<43:35,  6.21s/it, log potential=407, average acceptance=1]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [37], line 3
#       1 net = HamiltonianPerceptron(100, nonlinearity='tanh', prior='Gaussian', bias=True)
#       2 steps = 500
# ----> 3 posterior_samples, alpha, metrics = net.hamiltonian_monte_carlo(x, y, simulation_steps=steps, step_size=1e-4, leapfrog_steps=5000, metropolis_adjust=True)
#       4 print(alpha)
#
# File ~/dev/simple_nn/notebooks/../neural_networks/bayesian_nn.py:228, in HamiltonianPerceptron.hamiltonian_monte_carlo(self, x, y, simulation_steps, step_size, leapfrog_steps, pbar, metropolis_adjust)
#     226 current_sample = self.params_to_sample()
#     227 current_momentum = torch.randn_like(current_sample)
# --> 228 proposed_sample, proposed_momentum = self.get_hamilton_proposal(
#     229     x,
#     230     y,
#     231     current_sample,
#     232     current_momentum,
#     233     step_size=step_size,
#     234     leapfrog_steps=leapfrog_steps,
#     235 )
#     236 if metropolis_adjust:
#     237     log_alpha = self.compute_log_hmc_acceptance(
#     238         current_sample,
#     239         current_momentum,
#    (...)
#     243         y,
#     244     )
#
# File ~/dev/simple_nn/notebooks/../neural_networks/bayesian_nn.py:173, in HamiltonianPerceptron.get_hamilton_proposal(self, x, y, sample, momentum, step_size, leapfrog_steps)
#     170 new_momentum = momentum
#     172 for _ in range(leapfrog_steps):
# --> 173     new_sample, new_momentum = self.execute_leapfrog_step(
#     174         new_sample, new_momentum, x, y, step_size=step_size
#     175     )
#     177 return new_sample, new_momentum
#
# File ~/dev/simple_nn/notebooks/../neural_networks/bayesian_nn.py:150, in HamiltonianPerceptron.execute_leapfrog_step(self, sample, momentum, x, y, step_size)
#     142 def execute_leapfrog_step(
#     143     self,
#     144     sample: torch.Tensor,
#    (...)
#     148     step_size: float = 1e-4,
#     149 ) -> Tuple[torch.Tensor]:
# --> 150     momentum_prime = momentum - (step_size / 2) * self.get_potential_grad(
#     151         x, y, sample
#     152     )
#     153     new_sample = sample + step_size * momentum_prime
#     154     new_momentum = momentum_prime - (step_size / 2) * self.get_potential_grad(
#     155         x, y, new_sample
#     156     )
#
# File ~/dev/simple_nn/notebooks/../neural_networks/base_nets.py:154, in MCMCPerceptron.get_potential_grad(self, x, y, sample)
#     152 U = self.get_potential(x, y, sample)
#     153 self.zero_grad()
# --> 154 U.backward()
#     155 grads = torch.cat(
#     156     (self.layer_1.w.grad.flatten(), self.layer_2.w.grad.flatten())
#     157 )
#     158 return grads
#
# File ~/miniconda3/envs/simple_nn_env/lib/python3.9/site-packages/torch/_tensor.py:492, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     482 if has_torch_function_unary(self):
#     483     return handle_torch_function(
#     484         Tensor.backward,
#     485         (self,),
#    (...)
#     490         inputs=inputs,
#     491     )
# --> 492 torch.autograd.backward(
#     493     self, gradient, retain_graph, create_graph, inputs=inputs
#     494 )
#
# File ~/miniconda3/envs/simple_nn_env/lib/python3.9/site-packages/torch/autograd/__init__.py:251, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     246     retain_graph = create_graph
#     248 # The reason we repeat the same comment below is that
#     249 # some Python versions print out the first line of a multi-line function
#     250 # calls in the traceback and some print out the last line
# --> 251 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     252     tensors,
#     253     grad_tensors_,
#     254     retain_graph,
#     255     create_graph,
#     256     inputs,
#     257     allow_unreachable=True,
#     258     accumulate_grad=True,
#     259 )
#
# KeyboardInterrupt:

# %%
plt.plot(metrics["log potential"])
plt.title('Log Potential of Successive MCMC Samples')
plt.xlabel('Sample')
plt.ylabel('Log Potential')
plt.show()

# %% [markdown]
# ### Assess correlation between successive samples

# %%
burn_in = 10
# burn_in = 0

# %%
max_lag = 20
autocorrs = []
lags = [*range(max_lag)]
for lag in tqdm(lags):
    with torch.no_grad():
        autocorrs.append(autocorrelation(posterior_samples[burn_in:], lag=lag).mean())
# Out:
# 100%|██████████| 20/20 [00:00<00:00, 2201.16it/s]

# %%
plt.plot(lags, autocorrs)
plt.title('Average Autocorrelation Coefficient Across\nSample Dimensions vs Lag')
plt.xlabel('Lag')
plt.ylabel('Autocorrelation Coefficient')
plt.show()

# %% [markdown]
# ### Visualise the Posterior Predictive

# %%
thin = 10  # this should be around 1000
burn_in = 10
useful_samples = posterior_samples[burn_in:][::thin]
print("Number of Useful Samples: ", useful_samples.shape[0])
# Out:
# Number of Useful Samples:  9

# %%
test_x = torch.linspace(-2.5, 2.5, 500)
pred_samps = torch.zeros((useful_samples.shape[0], 500))

plt.scatter(x, y, color='C1', marker='2', label='Data', zorder=1000)
for i, sample in enumerate(useful_samples):
    with torch.no_grad():
        net.sample_to_params(sample)
        preds = net(test_x)
        pred_samps[i,:] = preds.squeeze()
    if i == 0:
        label = 'Network Prediction'
    else:
        label = None
    plt.plot(test_x, preds, color='grey', label=label, alpha=0.2)
    
plt.plot(test_x, pred_samps.mean(dim=0), color='black', label='Predictive Mean', alpha=1.0)
    
plt.ylim([-2.0, 2.0])
plt.xlim([-2.5, 2.5])
plt.grid(True)
plt.title('Hamiltonian Monte Carlo Prediction Samples')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
